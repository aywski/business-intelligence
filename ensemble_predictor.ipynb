# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('imdb_dataset.csv')

df
# Out:
#                                               Title  IMDb Rating  Year  \
# 0                                  End of the Spear          6.8  2005
# 1                                    Elvira Madigan          7.0  1967
# 2                      The Kid Stays in the Picture          7.3  2002
# 3                                     It Ain't Over          8.2  2022
# 4                                            Mahler          7.0  1974
# ...                                             ...          ...   ...
# 3168  The Lord of the Rings: The Return of the King          9.0  2003
# 3169                               Schindler's List          9.0  1993
# 3170                                The Dark Knight          9.0  2008
# 3171                                  The Godfather          9.2  1972
# 3172                       The Shawshank Redemption          9.3  1994
#
#      Certificates        Genre              Director  \
# 0           PG-13    Adventure             Jim Hanon
# 1              PG    Biography          Bo Widerberg
# 2               R  Documentary      Nanette Burstein
# 3              PG  Documentary           Sean Mullin
# 4              PG    Biography           Ken Russell
# ...           ...          ...                   ...
# 3168        PG-13       Action         Peter Jackson
# 3169            R    Biography      Steven Spielberg
# 3170        PG-13       Action     Christopher Nolan
# 3171            R        Crime  Francis Ford Coppola
# 3172            R        Drama        Frank Darabont
#
#                                           Star Cast  MetaScore  \
# 0               Louie LeonardoChad AllenJack Guzman       45.0
# 1        Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2                Robert EvansEddie AlbertPeter Bart       75.0
# 3                Andy AndresRoger AngellMarty Appel       79.0
# 4            Robert PowellGeorgina HaleLee Montague       66.0
# ...                                             ...        ...
# 3168        J.R.R. TolkienFran WalshPhilippa Boyens       94.0
# 3169           Liam NeesonRalph FiennesBen Kingsley       95.0
# 3170  Jonathan NolanChristopher NolanDavid S. Goyer       84.0
# 3171                 Mario PuzoFrancis Ford Coppola      100.0
# 3172            Tim RobbinsMorgan FreemanBob Gunton       82.0
#
#                                              Poster-src  Duration (minutes)
# 0     https://m.media-amazon.com/images/M/MV5BMTYxOT...               108.0
# 1     https://m.media-amazon.com/images/M/MV5BMmY2Nj...                91.0
# 2     https://m.media-amazon.com/images/M/MV5BZjhiZm...                93.0
# 3     https://m.media-amazon.com/images/M/MV5BZWViYW...                99.0
# 4     https://m.media-amazon.com/images/M/MV5BYzY4Mz...               115.0
# ...                                                 ...                 ...
# 3168  https://m.media-amazon.com/images/M/MV5BNzA5ZD...               201.0
# 3169  https://m.media-amazon.com/images/M/MV5BNDE4OT...               195.0
# 3170  https://m.media-amazon.com/images/M/MV5BMTMxNT...               152.0
# 3171  https://m.media-amazon.com/images/M/MV5BM2MyNj...               175.0
# 3172  https://m.media-amazon.com/images/M/MV5BNDE3OD...               142.0
#
# [3173 rows x 10 columns]

# %%
# extracting main actors from data (data mining)
df['Main Actor'] = df['Star Cast'].str.extract(r'([A-Z][a-z]+ [A-Z][a-z]+)')

# drop useless columns
df = df.drop(columns=["Poster-src", "Star Cast"])

df = df.drop_duplicates()

df
# Out:
#                              Title  IMDb Rating  Year Certificates  \
# 0                 End of the Spear          6.8  2005        PG-13
# 1                   Elvira Madigan          7.0  1967           PG
# 2     The Kid Stays in the Picture          7.3  2002            R
# 3                    It Ain't Over          8.2  2022           PG
# 4                           Mahler          7.0  1974           PG
# ...                            ...          ...   ...          ...
# 3166         The Godfather Part II          9.0  1974            R
# 3167                  12 Angry Men          9.0  1957     Approved
# 3170               The Dark Knight          9.0  2008        PG-13
# 3171                 The Godfather          9.2  1972            R
# 3172      The Shawshank Redemption          9.3  1994            R
#
#             Genre              Director  MetaScore  Duration (minutes)  \
# 0       Adventure             Jim Hanon       45.0               108.0
# 1       Biography          Bo Widerberg       66.0                91.0
# 2     Documentary      Nanette Burstein       75.0                93.0
# 3     Documentary           Sean Mullin       79.0                99.0
# 4       Biography           Ken Russell       66.0               115.0
# ...           ...                   ...        ...                 ...
# 3166        Crime  Francis Ford Coppola       90.0               202.0
# 3167        Crime          Sidney Lumet       97.0                96.0
# 3170       Action     Christopher Nolan       84.0               152.0
# 3171        Crime  Francis Ford Coppola      100.0               175.0
# 3172        Drama        Frank Darabont       82.0               142.0
#
#           Main Actor
# 0     Louie Leonardo
# 1      Pia Degermark
# 2       Robert Evans
# 3        Andy Andres
# 4      Robert Powell
# ...              ...
# 3166    Francis Ford
# 3167   Reginald Rose
# 3170  Jonathan Nolan
# 3171      Mario Puzo
# 3172     Tim Robbins
#
# [2762 rows x 9 columns]

# %%
print(f"The dataset contains: {len(df)} elements")
# Out:
# The dataset contains: 2762 elements

# %%
df.dtypes
# Out:
# Title                  object
# IMDb Rating           float64
# Year                    int64
# Certificates           object
# Genre                  object
# Director               object
# MetaScore             float64
# Duration (minutes)    float64
# Main Actor             object
# dtype: object

# %%
df_train = df.drop(columns=["Title"])

df_train
# Out:
#       IMDb Rating  Year Certificates        Genre              Director  \
# 0             6.8  2005        PG-13    Adventure             Jim Hanon
# 1             7.0  1967           PG    Biography          Bo Widerberg
# 2             7.3  2002            R  Documentary      Nanette Burstein
# 3             8.2  2022           PG  Documentary           Sean Mullin
# 4             7.0  1974           PG    Biography           Ken Russell
# ...           ...   ...          ...          ...                   ...
# 3166          9.0  1974            R        Crime  Francis Ford Coppola
# 3167          9.0  1957     Approved        Crime          Sidney Lumet
# 3170          9.0  2008        PG-13       Action     Christopher Nolan
# 3171          9.2  1972            R        Crime  Francis Ford Coppola
# 3172          9.3  1994            R        Drama        Frank Darabont
#
#       MetaScore  Duration (minutes)      Main Actor
# 0          45.0               108.0  Louie Leonardo
# 1          66.0                91.0   Pia Degermark
# 2          75.0                93.0    Robert Evans
# 3          79.0                99.0     Andy Andres
# 4          66.0               115.0   Robert Powell
# ...         ...                 ...             ...
# 3166       90.0               202.0    Francis Ford
# 3167       97.0                96.0   Reginald Rose
# 3170       84.0               152.0  Jonathan Nolan
# 3171      100.0               175.0      Mario Puzo
# 3172       82.0               142.0     Tim Robbins
#
# [2762 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_train['Main Actor'] = le.fit_transform(df_train['Main Actor'])
df_train['Director'] = le.fit_transform(df_train['Director'])
df_train["Certificates"] = le.fit_transform(df_train['Certificates'])
df_train["Genre"] = le.fit_transform(df_train['Genre'])

df_train = df_train[["IMDb Rating", "MetaScore"]]

df_train['Rating Difference'] = df_train['IMDb Rating'] - df_train['MetaScore']

df_train.dtypes
# Out:
# C:\Users\aywski\AppData\Local\Temp\ipykernel_34448\1368692974.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Rating Difference'] = df_train['IMDb Rating'] - df_train['MetaScore']
# IMDb Rating          float64
# MetaScore            float64
# Rating Difference    float64
# dtype: object

# %%
df_train
# Out:
#       IMDb Rating  MetaScore  Rating Difference
# 0             6.8       45.0              -38.2
# 1             7.0       66.0              -59.0
# 2             7.3       75.0              -67.7
# 3             8.2       79.0              -70.8
# 4             7.0       66.0              -59.0
# ...           ...        ...                ...
# 3166          9.0       90.0              -81.0
# 3167          9.0       97.0              -88.0
# 3170          9.0       84.0              -75.0
# 3171          9.2      100.0              -90.8
# 3172          9.3       82.0              -72.7
#
# [2762 rows x 3 columns]

# %%
from sklearn.ensemble import IsolationForest

iso_forest = IsolationForest(n_estimators=1000, contamination=0.002, random_state=42)
iso_forest.fit(df_train[['Rating Difference']])
anomalies = iso_forest.predict(df_train[['Rating Difference']])

anomaly_data = df_train[anomalies == -1]

df['Anomaly'] = anomalies

# %%
anomalous_movies = df[df['Anomaly'] == -1]

anomalous_movies[['Title', 'IMDb Rating', 'MetaScore']]
# Out:
#                                Title  IMDb Rating  MetaScore
# 74                        Modigliani          7.2       25.0
# 526                      Patch Adams          6.8       26.0
# 785                         Joe Dirt          6.0       20.0
# 1999  Hansel & Gretel: Witch Hunters          6.1       23.0
# 2008               Maximum Overdrive          5.4       24.0
# 2336                  One Man's Hero          6.0       24.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='IMDb Rating', y='MetaScore', hue='Anomaly', data=df, palette={1: 'blue', -1: 'red'})
plt.title('Anomalies in the difference between IMDb Rating and MetaScore')
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.show()
